# %% [markdown]
# ## Process ITC datasets to have gold answer extracted from output.

# %%
import pandas as pd
import os

# %%
itc_data = 'test_itc.jsonl'

# %%
df = pd.read_json(itc_data, orient='records', lines=True)
df.head()
# Out:
#                                          instruction input  \
# 0  Directions : There is a certain relation betwe...
# 1  There is a certain relation between two given ...
# 2  There is a certain relation between two given ...
# 3  Choose the word which is least like the other ...
# 4  Choose the word which is least like the other ...
#
#                                               output  \
# 0  This question is a type of verbal analogy. The...
# 1  The question is a form of analogy reasoning pr...
# 2  This is a question of analogy. The analogy is ...
# 3  The given question is a verbal reasoning quest...
# 4  This question is a test of understanding categ...
#
#                                            origin
# 0                    rs_aggarwal_book_exercise_1B
# 1                    rs_aggarwal_book_exercise_1B
# 2                    rs_aggarwal_book_exercise_1B
# 3  rs_aggarwal_book_exercise_illustrative example
# 4  rs_aggarwal_book_exercise_illustrative example

# %%
df.output[18]
# Out:
# "The relationship between the two words in the question is that the first word is a process that results in the creation of the second word. In this case, 'Evaporation' is the process through which 'Clouds' are formed.   We need to find a similar pair of words among the choices given.   (a) Mountain : Snow - This pair does not represent a process-result relationship. A mountain does not create snow.  (b) Pressure : Atmosphere - This pair does not represent a process-result relationship. Pressure is a result of the atmosphere, not the other way around.  (c) Book : Pages - This pair does not represent a process-result relationship. A book is made up of pages, but it does not create them.  (d) Tension : Breakdown - This pair represents a process-result relationship. 'Tension' can lead to a 'Breakdown', similar to how 'Evaporation' can lead to 'Clouds'.   Hence, the answer is (d)."

# %%
gold_ans_filter_words = ['therefore', 'hence', 'so', 'thus']

# %%
def split_text_on_pivot(large_text, pivot_word):
    """
    Splits the given text into two parts based on the pivot word.
    
    :param large_text: The text to be split
    :param pivot_word: The word on which to split the text
    :return: A tuple containing two parts of the text
    """
    if pivot_word in large_text:
        parts = large_text.split(pivot_word, 1)
        return parts[0], parts[1].strip()
    return large_text, None

# %%
split_text_on_pivot(df.output[18].lower(), gold_ans_filter_words[2])
# Out:
# ("the relationship between the two words in the question is that the first word is a process that results in the creation of the second word. in this case, 'evaporation' is the process through which 'clouds' are formed.   we need to find a similar pair of words among the choices given.   (a) mountain : snow - this pair does not represent a process-result relationship. a mountain does not create snow.  (b) pressure : atmosphere - this pair does not represent a process-result relationship. pressure is a result of the atmosphere, not the other way around.  (c) book : pages - this pair does not represent a process-result relationship. a book is made up of pages, but it does not create them.  (d) tension : breakdown - this pair represents a process-result relationship. 'tension' can lead to a 'breakdown', similar to how 'evaporation' can lead to 'clouds'.   ",
#  ', the answer is (d).')

# %%
PUNCTUATIONS = [',', '.']

# %%
def process_gold_text(text):
    # print(f'GOLD: {text}')
    if text[0] in PUNCTUATIONS:
        return " ".join(text.split(" ")[1:])
    else:
        return text

# %%
gold_answers = []
for row in df.iterrows():
    # print(row)
    ## Take the last sentence only:
    row_last_sent = " ".join(row[1].output.split('.')[-2:])
    # print('row_last_sent', row_last_sent)
    for word in gold_ans_filter_words:
        # print(f'Searching for word [{word}]')
        _, gold = split_text_on_pivot(row_last_sent.lower(), word)
        if gold and gold is not None:
            break
    # print(f"gold: [{gold}]")
    if gold is None:
        # print(f'\ngold answer not found for [{row_last_sent}]')
        gold = row[1].output
    # print(f"GOLD1: [{gold}]\n\n\n")
    gold = process_gold_text(gold)
    # print(f"GOLD2: [{gold}]\n\n\n")
    gold_answers.append(gold)

# df['gold_answer'] = gold_answers

# %%
gold_answers
# Out:
# ['the correct answer is (c) malaria',
#  "the answer is '(d) history'",
#  'the answer is (d) judgement',
#  'the correct answer is (c) oil',
#  'lotus (b) is the least like the other flowers in the group',
#  'the answer is (b) sword',
#  "the eagle is the odd one out in this group as it doesn't share the common characteristic of being flightless",
#  "the word 'river' is the odd one out as it does not contain stagnant water like the others",
#  'the arrow is the odd one out in this group of words because it is not a melee weapon and is not used while holding in hand, unlike the other four',
#  'the correct answer is (c) larva',
#  'the correct answer is (d) ampere',
#  'the answer is (c) beans',
#  'the correct answer is (d) novel: drama : literature',
#  'the choice that represents a similar relationship to the one in the question is (d) student : boy : girl',
#  'the correct answer is (b) accident : injury : pain',
#  'fail ahmed is the odd one out in this context',
#  "'exercising' is the odd one out as it is a general term, while the others are specific forms of exercising",
#  'the answer is (b) thailand',
#  'the answer is (d)',
#  'the correct answer is choice (c) moron : savant, as these words are antonyms of each other, matching the relationship in the original pair of words',
#  "The given question is a type of verbal reasoning question known as analogy. In these types of questions, we are given a pair of words that have a certain relationship and we have to find a similar relationship in the provided options. The relationship between the words 'Rotate' and 'Gyrate' is that they are synonyms, i.e., they mean the same thing. Now, we need to find a pair from the given options that are also synonyms.   Option (a) 'Putrefy : Reject' - These words are not synonyms. 'Putrefy' means to decay or rot, while 'Reject' means to dismiss or refuse.  Option (b) 'Anachorism : Cubism' - These words are not synonyms. 'Anachorism' means something or someone that is not in its correct historical or chronological time, especially a thing or person that belongs to an earlier time. On the other hand, 'Cubism' is an early 20th-century style and movement in art, especially painting, in which perspective with a single viewpoint was abandoned and use was made of simple geometric shapes, interlocking planes, and later, collage.  Option (c) 'Accolade : Criticism' - These words are not synonyms. In fact, they are antonyms. 'Accolade' means an award or privilege granted as a special honor or as an acknowledgment of merit, while 'Criticism' means the expression of disapproval of someone or something based on perceived faults or mistakes.  Option (d) 'Absolve : Exonerate' - These words are synonyms. Both 'Absolve' and 'Exonerate' mean to free someone from blame, responsibility, obligation, or guilt.  Hence, the correct answer is option (d) 'Absolve : Exonerate' as they have the same relationship as the original pair of words 'Rotate: Gyrate'. They are synonyms.",
#  "This is a question of analogy where we need to find the pair that does not share the same relationship as the others. The relationship in the pairs can be defined as a 'part-whole' relationship. In other words, the second item is a part of the first item.   (a) Flower: Petal - A petal is a part of a flower.  (b) Chair: Leg - A leg is a part of a chair.   (c) Circle: Arc - An arc is a part of a circle.   However, (d) Cover: Page - A page is not a part of a cover. Instead, a cover is a part of a book, which also includes pages. Therefore, the relationship in pair (d) is different from the others. The correct answer is (d) Cover: Page.",
#  "In this question, we are asked to find the pair of words that bears a different relationship than the others. \\n\\n1. Wine is made from grapes. So, the first is a product and the second is the substance used to make that product.\\n\\n2. Paper is made from pulp. Again, the first is a product and the second is the substance used to make that product. \\n\\n3. Shoes are made from leather. Once more, the first is a product and the second is the substance used to make that product. \\n\\n4. Wheat is a type of crop. In this case, the first is a subset or example of the second. It's not a product made from the second. \\n\\nTherefore, the pair (d) Wheat: Crop is differently related compared to the others. In all other pairs, the second is the substance which is used to prepare the first. In pair (d), Wheat is not made from Crop but rather, Wheat is a type of Crop.",
#  'the pair (c) merchant: business is differently related as compared to the other pairs',
#  'the answer is (c) watermelon',
#  'the stethoscope (d) is the odd one out because it is not an optical instrument like the other three',
#  'the answer is (d) direct',
#  'the correct answer is (b) color: faded, as it has the same relationship as the original pair of words',
#  'the answer is (c) building: cement',
#  'the pair of words that have the same relationship as the original pair of words is (c) avaricious: generous',
#  'the answer is new york',
#  'the odd one out is potassium',
#  'the answer is (d) whale',
#  'the answer is (d) chef: cook because this pair does not follow the same pattern as the others',
#  'option (d) ball: bat is the pair in which the words are differently related',
#  'pair (a) stallion: colt is differently related compared to the other pairs',
#  'the correct answer is (a)',
#  'the answer is (a)',
#  'the answer is (d) they are formed in sedimentary rocks',
#  "the answer is '(d) these are names of religious books '",
#  'the most appropriate description about mars, mercury, and venus is that they are the planets nearest to the earth',
#  'the answer is (b) horse : centaur, because a centaur is a mythical creature that is part-human, part-horse, just like a mermaid is part-human, part-fish',
#  'the correct answer is (c) promotion : merit',
#  'this is the correct answer',
#  'the answer is (e) mill',
#  'the answer is (d) kerala',
#  "the correct answer is (d) 'feasible'",
#  "the correct answer is (c) solid, as 'freeze' is the process of formation of 'solid'",
#  "the answer is '(d) temperature'",
#  "This question is based on the analogy reasoning concept. The relationship between the first two elements is that of 'a group of people' and 'their place of worship'. Specifically, Muslims worship in a Mosque. We need to find a similar relationship for Sikhs. The options are (a) Golden Temple (b) Medina (c) Fire Temple (d) Gurudwara. Among these, the correct answer is (d) Gurudwara, because it is the place of worship for Sikhs, similar to how a Mosque is a place of worship for Muslims.",
#  'the correct combination is (a) for i and (q) for ii, which corresponds to choice (a) aq',
#  'the correct answer is option (d)',
#  'the correct combination that maintains the same relationship is (c) bread and (r) clay, which corresponds to option (c) cr',
#  "the answer is 'ms'",
#  'the answer is (c) tvx',
#  'the answer is (d) tvxz',
#  'the answer is (c) ink : paper, because just as chalk is used to write on a blackboard, ink is used to write on paper',
#  "the pair with the same relationship as 'interrupt: speak' is 'interfere: assist' or option (d)",
#  "the pair that bears the same relationship as the given pair is 'hair: trim'",
#  "the pair that has the same relationship as the original pair of words 'numismatist: coins' is (a) philatelist: stamps",
#  'the correct answer is (a) program: function because it has the same relationship as the original pair of words; the first contains the details of the second',
#  'the correct answer is (d) chase: metal',
#  '63 is the number that is different from the rest as it is not a prime number',
#  'This problem is about identifying the number that does not fit the pattern. The given numbers are: 10, 26, 24, 21, and 18. The first step to solve this problem is to understand the common characteristic of most numbers. In this case, 10, 26, 24, and 18 are all even numbers. An even number is any integer that can be divided by 2 without a remainder. For instance, 10 divided by 2 equals 5, 26 divided by 2 equals 13, 24 divided by 2 equals 12, and 18 divided by 2 equals 9. All these operations result in whole numbers, meaning that the numbers are indeed even. The number 21, however, when divided by 2, gives 10.5, which is not a whole number. Therefore, 21 is the number that is different from the rest because it is an odd number, not an even number like the others. The answer is (d) 21.',
#  'the number that is different from the rest is 51',
#  'the correct answer is (b) fodder',
#  "This question is based on analogy reasoning. In analogy reasoning, the relationship between two words or phrases in a pair is applied to another pair of words or phrases. In this case, 'Abduction' and 'Kidnapping' are synonyms, meaning they have the same or nearly the same meaning. Therefore, we are looking for a word that is a synonym to 'Larceny'. Looking at the choices, the word 'Theft' is a synonym to 'Larceny'. Both 'Larceny' and 'Theft' refer to the act of taking someone else's property without their permission and with the intent to deprive the owner of it permanently. Therefore, the correct answer is '(a) Theft'. The other choices, 'Crime', 'Blackmail', and 'Sin', while related to 'Larceny', do not have the same meaning.",
#  "the answer is '(c) avenue'",
#  "the answer is 'client'",
#  "the answer is 'warden'",
#  'broom is related to sweep or clean in the same way as soap is related to wash',
#  "To find the surname of Rashmi, we need to understand the family tree given in the question. The question states that Rashmi is the daughter of Amit. Amit is a child of Mr. and Mrs. Sharma's eldest son and the youngest daughter of the Roys. This implies that Amit's father is the eldest son of the Sharmas and his mother is the youngest daughter of the Roys. Therefore, Amit's surname would be Sharma, as children traditionally take their father's surname. Consequently, Rashmi, being the daughter of Amit, would also have the surname Sharma. Hence, the surname of Rashmi is Sharma.\nTherefore answer is (a): Rashmi is the daughter of Amit who is, therefore the eldest son of Sharma and married to Veena, the youngest daughter of the Roys. So. the surname of Rashmi is Sharma.",
#  "sameer will be the grandson of monika's father",
#  "The problem provides a family tree of sorts. From the information provided, we know that Ashish is a child of Prashant Arora. Ashish married Monika and they have two sons, Sameer and Ajay. Therefore, Sameer is a grandchild of Prashant Arora. In many cultures, children inherit the last name of their father. Therefore, since Ashish, Sameer's father, has the last name 'Arora', it is highly likely that Sameer also has the last name 'Arora'. Hence, the surname of Sameer is Arora.\nTherefore answer is (c): Sameer is the son of Ashish who is the son of Prashant Arora. So. surname of Sameer is Arora.",
#  'the answer is (e)',
#  'the answer is (d)',
#  'the answer is (c)',
#  "answer is (c): the colour of the human blood is 'red' and as given, 'red' is called ‘yellow'  so, the colour of human blood is 'yellow",
#  'the man will sleep on the window”',
#  'ink is used for washing the clothes',
#  "The question asks to arrange the given words in alphabetical order and choose the one that comes first. In alphabetical order, the words would be arranged as follows: (c) War, (a) Wasp, (b) Waste, (d) Wrinkle, (e) Wrist. The reasoning behind this is that when we arrange words in alphabetical order, we look at the first letter of each word. All the words start with 'W', so we then look at the second letter. 'a' comes before 'a', 'a', 'r', 'r' in the alphabet, so 'War' is first.\nTherefore answer is (c): War. Wasp. Waste. Wrinkle, Wrist",
#  'answer is (a): science, scramble  script, scripture, scrutiny',
#  'answer is (e): integument  intellect, intelligent, intend, intense',
#  'answer is (a): schedule, scissors, scorpion, semester  sensitive',
#  'answer is (b): literary, litter, little  livelihood, livestock',
#  'answer is (e): manifest, mercerise  merchant, meridian, meticulous',
#  'The given question is a type of coding-decoding problem in reasoning. The problem provides two examples of how numbers are coded into letters. From these examples, we can decode the coding pattern and apply it to a new number. The coding pattern can be understood as follows: \\n\\nStep 1: From the first example, we understand that each number is coded into a specific letter. For instance, 1 is coded as E, 5 as G, 7 as K, 8 as P, and 9 as T. \\n\\nStep 2: From the second example, we know that 2 is coded as A, 3 as L, 4 as U, and 6 as R. \\n\\nStep 3: Now, we apply this coding pattern to the new number 23549. According to the pattern, 2 is coded as A, 3 as L, 5 as G, 4 as U, and 9 as T. \\n\\nTherefore, 23549 is coded as ALGUT. So, the answer to the question is option (c) ALGUT.\nTherefore answer is (c) In the given codes, the numbers are coded as shown : 1 5 7 8 9 2 3 4 6 E G K / P T A L U R i.e., 2 as A 3 as L, 5 as G. 4 as U and 9 as T. So. 23549 is coded as ALGUT.',
#  '396824 is coded as qlpnmf',
#  '23549 is coded as mpxdc',
#  '492311 is coded as ebwdss',
#  "In this question, we are asked to find the letters/numerals that come in the vacant places marked by (t). To solve this, we need to understand the pattern or correspondence between the given sequences of letters and numerals.   First, let's examine the given sequence: 'A D A C B B D C c 1 3 1 2 4 2 a b c d'.   We can observe the following patterns:  1. 'A' corresponds to 'a'  2. 'B' corresponds to 'b'  3. 'C' corresponds to 'c'  4. 'D' corresponds to 'd'  5. '1' corresponds to 'A'  6. '2' corresponds to 'B'  7. '3' corresponds to 'C'  8. '4' corresponds to 'D'  Now, we are asked to find the letters/numerals that come in the vacant places marked by '?'. By following the same pattern, we can deduce the following:  1. 'a' corresponds to 'C' (since '1' corresponds to 'A' and 'a' corresponds to '1')  2. 'b' corresponds to 'A' (since '2' corresponds to 'B' and 'b' corresponds to '2')  3. 'c' corresponds to 'D' (since '3' corresponds to 'C' and 'c' corresponds to '3')  4. 'd' corresponds to 'B' (since '4' corresponds to 'D' and 'd' corresponds to '4')  So, the sequence '? ? ?' corresponds to 'd, c, a, a', which is option (d).\nTherefore answer is (d) : Clearly, b corresponds to A 1 corresponds to C and a corresponds to 1. So, a corresponds to C. 2 corresponds to B and d corresponds to 2. So. d corresponds to B. So, the remaining letter ie., c corresponds to D. Thus. BDCC corresponds to d, c, a. a.",
#  'the code for calicut is 8251896',
#  'the code for piller is 318826',
#  'the code for search is 214673',
#  'Given the conditions for the team selection, we need to form a team of five, with two boys.1. **A and S have to be together**: If A (boy) is in the team, then S (girl) has to be in the team. This gives us two members already, one boy and one girl.2. **P cannot be put with R**: Since R (girl) cannot be with B (boy) as per another condition, we can safely include P (girl) in the team. Now, our team has one boy and two girls.3. **D and Q cannot go together**: Since we cannot have another boy in the team, D (boy) cannot be included in the team. Hence, Q (girl) can safely be included in the team. Now, our team has one boy and three girls.4. **C and E have to be together**: Since we already have one boy in the team, we cannot include both C and E (both boys) in the team. Hence, we cannot include C or E in the team.5. **R cannot be put with B**: R (girl) cannot be with B (boy). Since B (boy) is not in the team, we can include R in the team. Now, our team has one boy and four girls.6. Since we need two boys in the team, the only boy remaining to be included is B.So, the team will consist of A, B, S, P, and R. Hence, the correct option is not listed in the choices given in the question. The given answer in the question seems to be incorrect, as it does not match with our reasoning.\nTherefore answer is (a): If A is selected, S has to be selected. If B is selected, R cannot be selected If D is selected, Q cannot be selected. So. A D S Q R and B D S R Q are wrong. C E S P Q is not possible because S has to be accompanied with A',
#  'q s c e is wrong',
#  'p s c e is also wrong',
#  'answer is (a): place, plain, plane, player, plenty',
#  'answer is (e): acquire, amazed, disturb, reprimand, reverence',
#  'answer is (d): parasite, party, paste, petal, prick',
#  'Step 1: From the problem, we understand that there are five towns A, B, C, D and E. From these, two are hill stations and the rest are in plain. Two towns, which are in plain, are harbors. Also, four towns out of five are capitals and two are industrial towns.\\n\\nStep 2: We also know that the population of two towns is less than 5 lacs, one town has a population of 20 lacs and two towns have a population of more than 50 lacs.\\n\\nStep 3: There are two towns on the same latitudes and other two are on the same longitudes. The latitudes and longitudes of both harbors are different and out of these, one is an industrial town. The population of both industrial towns is more than 50 lacs.\\n\\nStep 4: B is a hill station while the longitudes of A and E are same. E is a harbor. The latitudes of D and C are same and the population of D is 20 lacs. Both the harbors are capitals and one of them is an industrial town.\\n\\nStep 5: From the given information, we can conclude that A which has the same longitude as E, cannot be a harbor and D having a population of 20 lacs cannot be an industrial town. So, E and D are harbors. E is an industrial town with a population of more than 50 lacs. Also, A having the same longitude as E, is a hill station. C cannot be a hill station because its latitude is the same as D, which is a harbor. So, B is the other hill station.\\n\\nStep 6: C is an industrial town with a population of more than 50 lacs. E and D are capitals since they are harbors. A, having the same longitude as a harbor, is also a capital. The population of D is 20 lacs, so the population of A and B is less than 5 lacs. So, the two towns whose population is less than 5 lacs are A and B.\nTherefore answer is (c): We analyze the given information as follows: Two are hill stations. Three are plains of which two are harbors. Four towns are capitals. Two towns are industrial. Two towns have population less than 5 lacs. One town has population 20 lacs. Two towns have population more than 50 lacs. Two towns are on same latitudes. B is a hill station. E is a harbor. Clearly, A which has the same longitude as E, cannot be a harbor and clearly, D having population 20 lacs cannot be an industrial town. So, it is a harbor. Thus, E and D are harbors. Clearly, one harbor is industrial town but D is not. So. E is an industrial town with population more than 50 lacs. Clearly, longitudes of a hill station and industrial town is same. So, A having same longitude as E, is a hill station. Latitudes of D and C are same and D is a harbor. So, C cannot be a hill station. So, B is the other hill station Thus, three plains are C, D, E. One industrial town is neither a hill station nor a harbor. So, C is an industrial town with population more than 50 lacs. Clearly, both harbors are capitals. So. E and D are capitals. The hill station A, having same longitude as a harbor, is also a capital. Population of D is 20 lacs. So, population of A and B is less than 5 lacs. Clearly, only one hill station is capital. So, C is the other capital. Clearly, population of A and B is less than 5 lacs.',
#  'c is the other capital clearly, b is not a capital',
#  'e is harbor, capital and industrial town',
#  "answer is (c): in the second and third statements, the common code word is 'sen' and the common word is 'but' so, 'sen' means 'but'",
#  "in the second statement, the remaining code 'ble' means 'where'",
#  "'baj' means 'dancing' thus, in the second statement, 'mint' means 'good'",
#  "The problem involves comparing the heights of five friends based on the given clues. The clues provided are:  1. Sachin is shorter than Kunal but taller than Rohan. This can be represented as Rohan < Sachin < Kunal.    2. Mohit is the tallest. This means Mohit is taller than all the other friends, so we can add him to our comparison: Rohan < Sachin < Kunal < Mohit.    3. Anuj is a little shorter than Kunal and little taller than Sachin. This can be represented as Sachin < Anuj < Kunal. When we add this to our existing comparison, we get: Rohan < Sachin < Anuj < Kunal < Mohit.  Now, by examining the final comparison, we can see that Rohan is shorter than all the other friends. Therefore, the answer to the question 'Who is the shortest?' is Rohan.\nTherefore answer is Let us denote the five boys by the first letter of their names, namely S. K. M. A and R. Then. R < S < K < M and S < A < K R<S<A<K<N!  (a): Rohan is shortest",
#  'From the information provided in the question, we can understand that:\\n\\nStep 1: Sachin is shorter than Kunal but taller than Rohan. This gives us the order: Rohan < Sachin < Kunal.\\n\\nStep 2: Mohit is the tallest. This extends our order to: Rohan < Sachin < Kunal < Mohit.\\n\\nStep 3: Anuj is a little shorter than Kunal and little taller than Sachin. This places Anuj between Sachin and Kunal. So, the final order is: Rohan < Sachin < Anuj < Kunal < Mohit.\\n\\nThe question asks for the person in the middle of this order. The middle position is occupied by Anuj. Therefore, Anuj is the person who will be in the middle when they stand in the order of their heights.\nTherefore answer is Let us denote the five boys by the first letter of their names, namely S. K. M. A and R. Then. R < S < K < M and S < A < K R<S<A<K<M  (d): Anuj is in the middle',
#  "Given the information, we can denote the five boys by the first letter of their names, namely S for Sachin, K for Kunal, M for Mohit, A for Anuj, and R for Rohan. The relationships between their heights are given as follows:  1. Sachin is shorter than Kunal but taller than Rohan: This gives us R < S < K.   2. Mohit is the tallest: This means M is greater than all, so we can append M to our previous inequality: R < S < K < M.   3. Anuj is a little shorter than Kunal and little taller than Sachin: This gives us S < A < K.   Combining all the information, we get R < S < A < K < M.   Hence, the second tallest is Kunal.   Note: The inequality symbol < is used here to denote 'is less than' in the context of height, so R < S means Rohan is shorter than Sachin.\nTherefore answer is Let us denote the five boys by the first letter of their names, namely S. K. M. A and R. Then. R < S < K < M and S < A < K R<S<A<K<N!  (b): Kunal is second tallest.",
#  "Let's break down the information given in the question. The question states that there are five friends named Sachin, Kunal, Mohit, Amy, and Rohan. It provides the following clues:  1. Sachin is shorter than Kunal but taller than Rohan.  2. Mohit is the tallest.  3. Anuj is a little shorter than Kunal and a little taller than Sachin.  From these clues, we can form a sequence of their heights in ascending order.  First, we know that Rohan is shorter than Sachin, so he is the shortest. This makes Rohan the first in the order of increasing heights.  Next, Sachin is taller than Rohan but shorter than Kunal and Anuj. This makes Sachin the second in the order.  Anuj is a little taller than Sachin and a little shorter than Kunal, which makes Anuj the third in the order.  Kunal is taller than Sachin and Anuj but shorter than Mohit, making Kunal the fourth in the order.  Lastly, Mohit is the tallest, which makes him the fifth in the order.  Therefore, in the order of increasing heights, Sachin will be the second.\nTherefore answer is Let us denote the five boys by the first letter of their names, namely S. K. M. A and R. Then. R < S < K < M and S < A < K R<S<A<K<N! (b): In the order of increasing heights i.e. shortest to tallest, Sachin is second.",
#  'the answer is (c)',
#  'the answer is (a)',
#  'the answer is (e)',
#  'the answer is (e)',
#  'the answer is (a)',
#  'x is the best knowledgeable person',
#  "The reasoning is based on the comparison of the intelligence levels of the kids. Here are the steps to find out the most intelligent child:\\n\\nStep 1: The first statement says, 'child A is less intelligent than child B', denoted as A < B. \\n\\nStep 2: The second statement says, 'child C is less intelligent than child D', denoted as C < D. \\n\\nStep 3: The third statement says, 'child B is less intelligent than child C', denoted as B < C. \\n\\nStep 4: The fourth statement says, 'child A is more intelligent than child E', denoted as E < A. \\n\\nStep 5: Now, combining the inequalities A < B, B < C, C < D, and E < A, we get E < A < B < C < D. \\n\\nStep 6: From this sequence, it is clear that child D is the most intelligent because D is greater than all other children in terms of intelligence.\nTherefore answer is (c): We have: A < B, C < D, B < C and E < A. So, the sequence becomes: E<A<B<C<D. Clearly, child D is the most intelligent.",
#  'This question is about comparing and ordering the heights of five boys, based on the given information.   Step 1: We begin by breaking down the given information into simpler, more manageable parts. We know that Vineet is taller than Manick, but shorter than Ravi. This can be represented as: Manick < Vineet < Ravi.  Step 2: The next piece of information is that Jacob is taller than Dilip but shorter than Manick. This can be represented as: Dilip < Jacob < Manick.  Step 3: By combining these two sequences, we can create a comprehensive order of heights for all five boys: Dilip < Jacob < Manick < Vineet < Ravi.  Step 4: From this sequence, it is clear that Ravi is the tallest boy in the group.  Therefore, the answer is (a) Ravi.\nTherefore answer is (a): In terms of height, we have: Manick < Vineet, Vineet < Ravi, Dilip < Jacob, Jacob < Manick. So. the sequence becomes: Dilip < Jacob < Manick < Vineet < Ravi. Clearly, Ravi is the tallest.',
#  'answer is (a): grandmother is one female, mother is another, wives of four sons are the four females and two daughters of all four sons are eight females  so, in all there are 1 + 1+ 4 + 8= 14 females',
#  'shalini is the daughter of lakshmi or lakshmi is the mother of shalini',
#  'anil is the grandson of bimal',
#  'answer is (d): all other groups contain two consecutive letters of the alphabet',
#  'answer is (b): all other groups contain two consecutive letters in reverse order',
#  'answer is (a): in all other groups, there is a gap of two letters between the given letters',
#  'answer is (d): all except mustard are food grains, while mustard is an oilseed',
#  'answer is (c): all except potato are fruit, while potato is a vegetable',
#  'answer is (c): all except table are used for sitting',
#  "In this question, we are given a series of letters with one missing letter, represented by a question mark. The provided series is 'U, O, I, ?, A'. The task is to identify the missing term from the given alternatives.   Step 1: Observe the pattern. The series consists of vowels 'A, E, I, O, U'.   Step 2: Notice that the series is written in reverse order. That is, the order of the vowels is reversed from 'U, O, I, ?, A' instead of the usual order 'A, E, I, O, U'.   Step 3: Identify the missing term. According to the reversed vowel order, the term that comes before 'A' and after 'I' is 'E'.   Therefore, the missing term in the series is 'E'. So, the correct answer is (a) E.\nTherefore answer is (a): The series consists of vowels A. E, I, O, U written in a reverse order.",
#  'answer is (e): the series consists of alternate letters in reverse order',
#  "The given series is 'A. B, D. G, ?'. We can analyze this as follows: \\n\\nStep 1: The series is based on the English alphabets. The first term is 'A'. The next term is 'B', which is one step forward from 'A'. \\n\\nStep 2: The third term is 'D'. If we observe, 'D' is two steps forward from 'B'. \\n\\nStep 3: The fourth term is 'G', which is three steps forward from 'D'. \\n\\nStep 4: Following this pattern, the next term should be four steps forward from 'G'. If we count four letters forward from 'G' in the English alphabet, we reach 'K'. \\n\\nTherefore, the missing term in the series is 'K'.\nTherefore answer is (c): The first, second, third, letters of the series are respectively moved one, two, three. steps forward to obtain the successive terms.",
#  "the answer to the question 'at a time when there are floods and a storm also blows, which road(s) can be used?' is only road 3 \ntherefore answer is (c)",
#  'answer is (c)',
#  'answer is (d)',
#  'answer is (d): each other group contains 4 consecutive letters',
#  'answer is (b): all other groups contain letters in reverse alphabetical order',
#  'answer is (d): all other groups contain three consecutive letters with second letter repeated twice',
#  'answer is (d): first is prepared by the second',
#  'answer is (a): pongee is a type of silk and shallot is a kind of boat',
#  'answer is (b): one is followed by other',
#  "in the second statement, either 5 or 8 stands for 'caste'",
#  "in the third statement, means 'ripe'",
#  "in the second statement, '8' means 'see'",
#  "the man is rita's son",
#  "the man is seema's cousin",
#  'the woman is man’s mother',
#  'answer is (a) : any change in the first is made by means of second',
#  'answer is (b) : first is preserved in the form of second',
#  'answer is (c) : rickets is a disease found in children; osteomalacia is found in adults',
#  'answer is (a): this is the only group containing a vowel',
#  'answer is (d): in all other groups, the letters are in reverse alphabetical order',
#  'answer is (a): all other groups contain alternate letters of the alphabet in order',
#  "The given question is a word rearrangement problem where a sequence of words are rearranged according to a specific rule in each step. The rule here is to rearrange the words alphabetically by altering the position of only one word in each step. Given this rule, we are asked to find the input that will result in a specific output at Step IV.\\n\\nThe output at Step IV is: 'an apple at cot was red on one side'. To find the input that resulted in this output, we need to reverse-engineer the steps. \\n\\nStarting from Step IV, we rearrange the words back to their previous places in each step. Doing so, we get:\\n\\nStep III: an apple at was cot red on one side\\nStep II: an apple was cot red on at one side\\nStep I: an was cot red on at one apple side\\n\\nSo, the initial input was 'was cot red an on at one apple side'.\\n\\nTherefore, comparing with the given choices, the answer is (a) 'was cot red an on at one apple side' as it matches with our derived input.\nTherefore answer is Clearly, in the given arrangement, the words have been arranged alphabetically in a sequence, altering the position of only one word in each step.  Tracing the output steps for each of the given inputs, we find that Step IV for (a) is the same as that given in the questions, while in (6) and (c), the desired output occurred at Step III. Input: was cot red an on at one apple side Step I: an was cot red on at one apple side Step II: an apple was cot red on at one side Step III: an apple at was cot red on one side Step IV: an apple at cot was red on one side So. the answer is (a).",
#  'the answer is (d)',
#  'the answer is (a)',
#  'answer is clearly, in the given arrangement, the numbers have been arranged in descending order in a sequence, altering the position of only one number in each step  (a): input: 25 08 35 11 88 67 23 step i: 88 25 08 35 11 67 23 step ii: 88 67 25 08 35 11 23 step iii: 88 67 35 25 08 11 23 step iv: 88 67 35 25 23 08 11 step v: 88 67 35 25 23 11 08',
#  'answer is clearly, in the given arrangement, the numbers have been arranged in descending order in a sequence, altering the position of only one number in each step   (c): input: 09 25 16 30 32 19 17 06 step i: 32 09 25 16 30 19 17 06 step ii: 32 30 09 25 16 19 17 06 step iii: 32 30 25 09 16 19 17 06',
#  'it is the last step',
#  'the pattern ab is repeated',
#  'the pattern abb, aab is repeated',
#  'the pattern aba is repeated',
#  "answer is (e): the given sequence may be analysed as under: 4 / 45 / 453 / 4531 / 45312 / 45 / 453 / 453 following the above sequence, the next number is 1 which stands for 'run'",
#  'the student will have to sit down 6 times \ntherefore answer is (c): clearly, the student will have to sit down at the places marked by boxes: 1 2 3 [4] 2 3 1 [4 4] 3 2 2 1 2 [4] 3 1 [4 4] 1 2',
#  "'Firstly, we need to find the numbers between 1 and 45 that are exactly divisible by 3. These numbers are obtained by multiplying 3 by each whole number. They will be 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45. These are 15 numbers. If these numbers are arranged in ascending order with the smallest number on top, the sequence will be as follows: 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45. Counting from the top, the ninth number in this sequence is 27. Therefore, the ninth number from the top that is exactly divisible by 3 between 1 and 45 is 27.'\nTherefore answer is (d): The required numbers in ascending order are: 3. 6. 9. 12, 15. 18. 21, 24. 27, 30, 33, 36, 39, 42, 45. If the minimum number i.e., 3 is considered to be at the top. the ninth number from the top is 27.",
#  'option d is the most appropriate choice \ntherefore answer is (d)',
#  'answer is (b)',
#  'answer is (a)',
#  'answer is (c): the candidate satisfies condition (5) instead of condition (3)',
#  'answer is (e): the age of the candidate is not mentioned',
#  'answer is (a): all conditions of eligibility are satisfied',
#  'answer is (e): there are ten letters between h and s and as such, there is no letter which lies exactly in the middle',
#  'answer is (b): clearly, l is the letter to the immediate left of m',
#  "This question is about positional relationships within the English alphabet series. The first step is to find the letter which is fourth to the left of 'I'. When we count to the left from 'I' in the alphabet, we find that the fourth letter to the left is 'E'. Now, we need to find the sixteenth letter to the right of 'E'. If we count to the right from 'E' in the alphabet, we find that the sixteenth letter to the right is 'U'. Therefore, the letter that is sixteenth to the right of the letter which is fourth to the left of 'I' is 'U'.\nTherefore answer is (c): Clearly, the fourth letter to the left of I is E. The sixteenth letter to the right of E is U.",
#  'answer is (e)',
#  'answer is (c)',
#  "the answer is (b) story '\ntherefore answer is (b)",
#  "the word that cannot be made from the letters of the word 'carpenter' is 'painter' (choice c) \ntherefore answer is (c)",
#  "the word that cannot be formed from the letters of 'teachers' is 'chair' \ntherefore answer is (b)",
#  "the word that cannot be formed from the letters of 'consolidate' is 'lentil' (choice (a)) \ntherefore answer is (a)",
#  '1st march is thursday and 3rd march is saturday',
#  'answer is (b): if the year is not a leap year, then the last day of the year is the same as the first day',
#  "Firstly, we need to understand that the day of the week advances by one day from one year to the next because a year (not including leap years) is 365 days and 365 is 1 more than a multiple of 7 (the number of days in a week). This means that if 18th February, 1997 was a Tuesday, then 18th February, 1998 would be the next day of the week, which is Wednesday. However, we need to find the day for 18th February, 1999. So we need to advance one more day from Wednesday. This brings us to Thursday. Therefore, 18th February, 1999 falls on a Thursday. It's also important to note that 1997 and 1998 are not leap years, so we don't have to account for the extra day in February. If they were, we would need to adjust our calculation.\nTherefore answer is (c): 18th February, 1997 was Tuesday. So. 18th February. 1998 was Wednesday. 18th February. 1999 will be Thursday.",
#  'answer is (b): condition (4) is violated',
#  'answer is (c): condition (4) is missing',
#  'answer is (c): being a far relative of a freedom fighter, the candidate will not get the benefit',
#  "'This is a question of biology and logic. The assertion (A) states that leaves of plants are green. This is true as the green color in leaves is due to the presence of chlorophyll, a pigment that helps plants absorb sunlight for photosynthesis. The reason (R) states that plants contain chromoplasts, the green pigment. This is incorrect. While it is true that plants contain chromoplasts, these are not the green pigments. Chromoplasts are responsible for the synthesis and storage of pigments that are yellow, orange, or red. The green pigment in plants is chlorophyll, not chromoplasts. Therefore, the correct answer is (c) A is true but R is false.'\nTherefore answer is (c): Leaves of plants are green because they contain the green pigment, chlorophyll. However, plants contain chromoplasts but they are not green pigments.",
#  "The question is a type of reasoning question where we have to evaluate the truth value of two statements: an assertion (A) and a reason (R) and determine the relationship between them. The assertion (A) is 'We prefer to wear white clothes in winter' and the reason (R) is 'White clothes are good reflectors of heat'. The first step is to evaluate the truth value of each statement.   Starting with (A), it is generally accepted that in winter, people prefer to wear dark clothes because they absorb more heat and thus help keep the body warm. Therefore, the assertion (A) is false.   Now, let's consider (R). The statement 'White clothes are good reflectors of heat' is scientifically accurate. White clothes reflect all wavelengths of light, including infrared radiation which we perceive as heat. Therefore, they help to keep the body cool by reflecting heat away, which is particularly useful in summer. So, the reason (R) is true.   Thus, the correct answer is (d) A is false but R is true. The assertion is incorrect because we usually prefer to wear dark clothes in winter as they absorb heat, while the reason is correct as white clothes reflect heat away.\nTherefore answer is (d): We prefer to wear dark clothes in winter because they absorb the heat and keep the body warm. However, white clothes are good reflectors of heat and are worn in summer.",
#  'answer is (c): leakages in household gas cylinders can be detected because of the strong smell of ethyl mercaptan mixed with lpg',
#  "To solve this problem, we will follow these steps: 1. Identify the third, fifth, eighth, and tenth letters of the word 'DISTRIBUTE'. They are S, R, U, and E, respectively. 2. Try to form a meaningful word with these letters. We can see that these letters form the word 'SURE'. 3. Now, we need to identify the third letter of the word 'SURE'. The third letter is 'R'. So, the answer is 'R'. If no meaningful word could be formed, we would choose 'X'. If multiple words could be formed, we would choose 'M'. In this case, only one meaningful word, 'SURE', can be formed. Therefore, the answer is 'R'.\nTherefore answer is (b): The third, fifth, eighth and tenth letters of the word DISTRIBUTE are S, R. U and E respectively. The word formed is SURE and its third letter is R.",
#  "The question requires us to form a meaningful word using specific letters from the word 'ADMINISTRATION' and then identify the third letter from the right end of the word we form. Let's break down the steps:  1. Identify the first, fourth, ninth, and fourteenth letters of the word 'ADMINISTRATION'. These are 'A', 'I', 'R', and 'N' respectively.   2. Arrange these letters to form a meaningful word. The word that can be formed is 'RAIN'.  3. Now, we need to find the third letter from the right end of the word 'RAIN'. In English, we read from left to right, but here we are asked for the third letter from the right, which means we count from the end of the word to the beginning.   4. Counting from right (from 'N' to 'R'), the third letter is 'A'.    Therefore, the third letter of the word 'RAIN' from the right end is 'A'.\nTherefore answer is (a): The first, fourth, ninth and fourteenth letters of the word ADMINISTRATION are A. I. R and N respectively. The word formed is RAIN The third letter from the right end is A.",
#  'answer is (e): tho second, fifth and eighth letters of the word caretaker are a, t and e respectively  the words formed are eat, ate and t e a',
#  'the answer is (c)',
#  'the answer is (e)',
#  'the answer is (c)',
#  'the answer is (c)',
#  'the answer is (c)',
#  "the rotation of the earth directly influences the direction of the wind, making the reason a correct explanation of the assertion '\ntherefore answer is (a)",
#  'both the assertion and reason are true and the reason correctly explains the assertion \ntherefore answer is (a)',
#  'answer is (a)',
#  'answer is (a)',
#  'answer is (c)',
#  'answer is (b)',
#  'answer is (a): carbon monoxide, when inhaled, combines with hemoglobin of blood to form carboxyhemoglobin which inhibits the transport of oxygen',
#  'answer is (a): higher above the sea level, temperature decreases at the rate of 1°c for every 165 metres of ascent making mountain peaks colder',
#  "rb the sun's rays but reflects them",
#  'conditions (6) and (4) are to be applied to him',
#  'answer is (b): condition (4) is to be applied',
#  'answer is (d): condition (3) is to be applied',
#  'answer is (b): clearly, number of trees in the row = (4 + 1 + 4) = 9',
#  "Let's break down the problem:  Step 1: Understand the problem. We know the position of Amrita and Mukul in the queue and we also know that Mamta is exactly in between them. We need to find the position of Mamta from the front of the queue.  Step 2: Calculate the number of people between Amrita and Mukul. This can be calculated by subtracting the position of Amrita and Mukul from the total number of people in the queue. So, the number of people between Amrita and Mukul = 50 - 10(Amrita's position) - 25(Mukul's position) = 15.  Step 3: Since Mamta is in the middle of these 15 people, her position will be half of this number from Amrita's position. So, Mamta's position from Amrita is 15/2 = 7.5. Since positions in the queue are in whole numbers, we round up to the nearest whole number which is 8.  Step 4: To find the position of Mamta from the front, we add her position relative to Amrita to Amrita's position. So, Mamta's position from the front = 10(Amrita's position) + 8(Mamta's position from Amrita) = 18.  Therefore, Mamta is 18th from the front of the queue.\nTherefore answer is (c): Number of persons between Amrita and Mukul =50-(10+25)=15. Since Mamta lies in middle of these 15 persons, so Mamta's position is 8th from Amrita i.e. 18th from the front. ",
#  'answer is (a): clearly, number of students in the class =(15 + 1 + 48) = 64',
#  'sufficient',
#  "This question is asking for the exact number of visitors who saw the exhibition yesterday. To answer this question, we need to have the exact number of people who attended the exhibition.\\n\\nLooking at statement I, it tells us that each entry pass holder can take up to three persons with him/her. This information tells us the maximum number of people that could attend per pass, but it does not give us the exact number of people who did attend. Therefore, statement I alone is not sufficient to answer the question.\\n\\nStatement II tells us that 243 passes were sold yesterday. This gives us the minimum number of people who could have attended the exhibition, but it does not give us the exact number because we don't know how many additional people each pass holder brought with them. Therefore, statement II alone is not sufficient to answer the question.\\n\\nEven if we combine the two statements, we can only determine that the number of visitors is between 243 (if each pass holder came alone) and 972 (if each pass holder brought 3 additional persons). But we can't determine the exact number of visitors. So, even the data in both the statements together are not sufficient to answer the question.\\n\\nHence, the answer is (d): The data even in both the statements together are not sufficient to answer the question.\nTherefore answer is (d): From the two statements, we find that maximum (243 x 3) i.e. 729 visitors saw the exhibition. But the exact number cannot be determined",
#  "'The question is asking for the total sale of the company. This can be found by knowing the number of units sold and the cost per unit, and then multiplying these two values together. Statement I tells us that the company sold 8000 units of product A, each costing Rs 25. By multiplying these two values together, we find that the total sale from product A is 8000 units * Rs 25/unit = Rs 200000. However, to know the total sale of the company, we would need to know if the company sells any other products. Statement II tells us that the company has no other product line. This means that the sale of product A is the total sale of the company. Therefore, the total sale of the company is Rs 200000. Both statements I and II are needed to answer the question, so the answer is (e): The data in both the statements together are needed.'\nTherefore answer is (e): From I, total sale of product A = Rs. (8000 x 25) = Rs. 200000. From II, we know that the company deals only in product A. This implies that sale of product A is the total sale of the company, which is Rs. 200000.",
#  "'The assertion is that Diamond is used for cutting glass which is true. Diamonds, due to their extreme hardness and specific crystal structure, are able to cut glass. This property is not related to the refractive index of the diamond, but rather to its hardness and structure. The reason given is that Diamond has a high refractive index. This is also true. A high refractive index means that light travels slower in the diamond than in air, causing the light to bend sharply. This property gives diamonds their characteristic sparkle. But this reason is not the correct explanation of why diamonds are used for cutting glass. The hardness and crystal structure of the diamond, not its refractive index, make it useful for cutting glass. So, both the assertion and reason are true, but the reason is not the correct explanation of the assertion.'\nTherefore answer is (b): Diamond is very hard due to its rigid three-dimensional structure and so, it is used for cutting glass. Refractive index of diamond is high and gives it the greater transparency and brilliance.",
#  'they say',
#  'answer is (c): eskimos live in 6now houses called igloos because snow, being a bad conductor of heat, these houses are warm inside',
#  'answer is (b)',
#  'the answer is (a) 2,4,1,5,3 \ntherefore answer is (a)',
#  'answer is (c)',
#  'the answer is (b)',
#  'the answer is (d)',
#  'the answer is (b)',
#  'answer is (b): in the code, we have alternately one letter one step behind and the other one step ahead of the corresponding letter in the word',
#  "the word coded as 'serpevre' is 'preserve' \ntherefore answer is (e): in the code, the first four and the last four letters of the word are separately interchanged",
#  'answer is (a): each letter of the word is four steps behind the corresponding letter of the code',
#  'ii is also implicit',
#  'ii is also implicit',
#  'option a is correct',
#  'n of the man in the photograph',
#  "the man is woman's husband",
#  "The question asks about the relationship between Deepak and the boy playing football. We can break down the sentence as follows:  Step 1: 'My father's wife' would be Deepak's mother, because the father's wife is typically the mother.  Step 2: 'The daughter of my father's wife' would be Deepak's sister. This is because the daughter of Deepak's mother would be Deepak's sister.   Step 3: 'The younger of the two brothers of the daughter of my father's wife' would be Deepak's younger brother. This is because the younger brother of Deepak's sister would also be Deepak's brother.   Therefore, the boy playing football is Deepak's brother.\nTherefore answer is (b): Father's wife — Mother; Mother's daughter — Sister; Sister's younger brother — My younger brother. So. the boy is Deepak's brother.",
#  'answer is (c)',
#  'answer is (a)',
#  'the correct answer is (c) 2 and 4 \ntherefore answer is (c)',
#  '"The paragraph discusses the role of advertising in manufacturing and the risks that manufacturers take in trying to predict consumer behavior. The best supported statement is choice (e) that manufacturers must depend upon final consumers for the success of their undertakings. This is because the paragraph points out that manufacturers distribute goods in advance of their final selection by consumers, indicating that consumer choices ultimately determine the success of the manufacturer\'s undertakings. Choice (a) is incorrect because the passage states that manufacturers distribute goods in advance of their final selection by consumers, not directly to them. Choice (b) is incorrect because the passage does not suggest that advertising can eliminate the risk of overproduction. Choice (c) is incorrect because the passage describes the risks that manufacturers take as \'enormous\', not \'moderate\'. Choice (d) is incorrect because the passage states that predicting consumer behavior is a risk, not something that can be done with great accuracy."\nTherefore answer is According to the passage, it is very difficult for the manufacturer to predict the consumers\' response to his products. But by advertising, he can stimulate the consumers to buy his product. So, the theme of the paragraph is best mentioned in (b). Hence. (b) is the answer. (a) is incorrect because it is mentioned in the paragraph that manufacturers distribute goods in advance of their demands and not directly to the consumers. (c) is wrong because according to the passage, manufacturers take \'enormous\' and not \'moderate\' risks. (d) is wrong because it is mentioned in the passage that manufacturers take great risk in predicting what the consumers want, (e) is a true statement but it does not depict the complete theme of the passage.',
#  'the answer is (c) "\ntherefore answer is (c)',
#  'answer is (c)',
#  'ii is not implicit',
#  'ii is also not implicit',
#  'ii is also implicit',
#  '"Based on the clues given, we know that: \\nStep 1: Mohit is the tallest, so he\'s at the end of the line. \\nStep 2: Sachin is shorter than Kunal but taller than Rohan, which gives us the order: Rohan < Sachin < Kunal. \\nStep 3: Anuj is a little shorter than Kunal and little taller than Sachin, so he fits between Sachin and Kunal, giving us the order: Rohan < Sachin < Anuj < Kunal. \\nStep 4: As Mohit is the tallest, we add him to the end of the line, giving us the final order: Rohan < Sachin < Anuj < Kunal < Mohit. \\nStep 5: If they stand in the order of increasing heights, the second person will therefore be Sachin."\nTherefore answer is Let us denote the five boys by the first letter of their names, namely S. K. M. A and R. Then. R < S < K < M and S < A < K R<S<A<K<N! (b): In the order of increasing heights i.e. shortest to tallest, Sachin is second.',
#  "'Given the information, we can establish a height order among the friends. We know that Mohit is the tallest, which makes him the highest point in our order. Then we have information about Sachin, Kunal and Rohan. Sachin is shorter than Kunal but taller than Rohan, so we can place them in our height order as Rohan < Sachin < Kunal. Now, we are told that Anuj is a little shorter than Kunal and a little taller than Sachin, so we can add him to our order: Rohan < Sachin < Anuj < Kunal. Since we are looking for someone who is taller than Anuj but shorter than Mohit, the only person who fits this description is Kunal. Therefore, the answer is Kunal.'\nTherefore answer is Let us denote the five boys by the first letter of their names, namely S. K. M. A and R. Then. R < S < K < M and S < A < K R<S<A<K<N!  (a): Kunal is taller than Anuj but shorter than Mohit.",
#  'the answer is (e)',
#  'only i follow',
#  'only course ii follows',
#  'both the courses follow',
#  'the inference is \'probably false\' though not definitely false in the light of the facts given, which corresponds to option (d) "\ntherefore answer is (d)',
#  'answer is (c)',
#  'the correct answer would be \'(b) if the inference is ‘probably true’ though not definitely true in the light of the facts given\' "\ntherefore answer is (a)',
#  'answer is (a)',
#  'the answer is (d) if the data even in both the statements together are not sufficient to answer the question "\ntherefore answer is (d)',
#  'answer is (e)']

# %%
df['gold_answer'] = gold_answers
# head_tail = os.path.split(itc_data)
# itc_save_path = f"{head_tail[0]}_gold.{head_tail[1].split('.')[1]}"
df.to_json('test_itc_gold.jsonl', orient='records', lines=True)
